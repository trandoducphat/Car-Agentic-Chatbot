# %%
import sys
import os

root_dir = r"D:/BIN/Project/agentic_chatbot"
os.chdir(root_dir)
sys.path.append(root_dir)

# %%
from app.intent.base import Intent

# %%
state = Intent("FILTER_BY_PRICE")
print(state)
# Out:
# Intent.FILTER_BY_PRICE
